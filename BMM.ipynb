# %%
bd.to_excel('/Users/ssd/Downloads/BMM_2.xlsx')

# %%
import pandas as pd
import numpy as np

# %%
bd = pd.read_csv('Копия_base_test.xlsx - weather.csv')

# %%
bd['type_of_car'] = bd['type_of_car'].str.replace('ФУСО', 'Фусо')
bd['type_of_car'] = bd['type_of_car'].str.replace('боковая', 'Боковая')
bd['type_of_car'] = bd['type_of_car'].str.replace('бункеровоз', 'Бункеровоз')
bd['type_of_car'] = bd['type_of_car'].str.replace('задняя', 'Задняя')
bd['type_of_car'] = bd['type_of_car'].str.replace('кму', 'КМУ')
bd['type_of_car'] = bd['type_of_car'].str.replace('мультилифт', 'Мультилифт')
bd['type_of_car'] = bd['type_of_car'].str.replace('самосвал', 'Самосвал')
bd['type_of_car'] = bd['type_of_car'].str.replace('фусо', 'Фусо')
bd.head()
# Out:
#    day  mounth day_of_week type_of_car number_of_car mass_of_trash  \
# 0    1  Январь     пятница  Бункеровоз     В297КЕ147          4300
# 1    1  Январь     пятница  Бункеровоз     К721ВС154          5180
# 2    1  Январь     пятница  Бункеровоз     Н726РУ154          5400
# 3    1  Январь     пятница  Бункеровоз     Н991НУ154          4960
# 4    1  Январь     пятница  Мультилифт     К801ВА154          3220
#
#   size_of_trash      density  tmin  tmax
# 0            48  89,58333333  -28°  -32°
# 1            40        129,5  -28°  -32°
# 2            64       84,375  -28°  -32°
# 3            48  103,3333333  -28°  -32°
# 4         36,66  87,83415166  -28°  -32°

# %%
bd = bd[bd['size_of_trash'] != '0']
bd = bd[bd['mass_of_trash'] != '0']
bd = bd[bd['mass_of_trash'] != '-']
bd['mass_of_trash'] = bd['mass_of_trash'].str.replace(' ', '').str.replace(',', '.').astype(float)
bd['size_of_trash'] = bd['size_of_trash'].str.replace(' ', '').str.replace(',', '.').astype(float)
bd['number_of_car'] = bd['number_of_car'].str.replace(' ', '')
bd['density'] = bd['density'].str.replace(' ', '').str.replace(',', '.').astype(float)
bd['tmin'] = bd['tmin'].str.replace('°', '').astype(float)
bd['tmax'] = bd['tmax'].str.replace('°', '').astype(float)
bd['taverage'] = (bd['tmax'] + bd['tmin']) / 2
bd.head()
# Out:
#    day  mounth day_of_week type_of_car number_of_car  mass_of_trash  \
# 0    1  Январь     пятница  Бункеровоз     В297КЕ147         4300.0
# 1    1  Январь     пятница  Бункеровоз     К721ВС154         5180.0
# 2    1  Январь     пятница  Бункеровоз     Н726РУ154         5400.0
# 3    1  Январь     пятница  Бункеровоз     Н991НУ154         4960.0
# 4    1  Январь     пятница  Мультилифт     К801ВА154         3220.0
#
#    size_of_trash     density  tmin  tmax  taverage
# 0          48.00   89.583333 -28.0 -32.0     -30.0
# 1          40.00  129.500000 -28.0 -32.0     -30.0
# 2          64.00   84.375000 -28.0 -32.0     -30.0
# 3          48.00  103.333333 -28.0 -32.0     -30.0
# 4          36.66   87.834152 -28.0 -32.0     -30.0

# %%
densityMax = np.percentile(bd['density'].dropna(), 99.9)
densityMin = np.percentile(bd['density'].dropna(), 0.1)
bd = bd[bd['density'] > densityMin][bd['density'] < densityMax]

massMax = np.percentile(bd['mass_of_trash'].dropna(), 99.9)
massMin = np.percentile(bd['mass_of_trash'].dropna(), 0.1)
bd = bd[bd['mass_of_trash'] > massMin][bd['mass_of_trash'] < massMax]

sizeMax = np.percentile(bd['size_of_trash'].dropna(), 99.9)
sizeMin = np.percentile(bd['size_of_trash'].dropna(), 0.1)
bd = bd[bd['size_of_trash'] > sizeMin][bd['size_of_trash'] < sizeMax]
# Out:
# /var/folders/85/nvry22pd6nx6pfd1c1h6z_nr0000gp/T/ipykernel_26740/3123306523.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   bd = bd[bd['density'] > densityMin][bd['density'] < densityMax]
# /var/folders/85/nvry22pd6nx6pfd1c1h6z_nr0000gp/T/ipykernel_26740/3123306523.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   bd = bd[bd['mass_of_trash'] > massMin][bd['mass_of_trash'] < massMax]
# /var/folders/85/nvry22pd6nx6pfd1c1h6z_nr0000gp/T/ipykernel_26740/3123306523.py:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   bd = bd[bd['size_of_trash'] > sizeMin][bd['size_of_trash'] < sizeMax]

# %%
bd[bd['mounth'] == 'Февраль']
# Out:
#        day   mounth  day_of_week type_of_car number_of_car  mass_of_trash  \
# index
# 1798     1  Февраль  понедельник  Бункеровоз     В297КЕ147         3820.0
# 1799     1  Февраль  понедельник  Бункеровоз     К721ВС154         3740.0
# 1800     1  Февраль  понедельник  Бункеровоз     Н726РУ154         5180.0
# 1801     1  Февраль  понедельник  Бункеровоз     Н991НУ154         9700.0
# 1802     1  Февраль  понедельник  Мультилифт     Н416НС154         5620.0
# ...    ...      ...          ...         ...           ...            ...
# 3249    28  Февраль  воскресенье      Задняя     Н590ТТ154        20440.0
# 3250    28  Февраль  воскресенье      Задняя     Н864ТТ154        12360.0
# 3251    28  Февраль  воскресенье      Задняя     О369АР750        11420.0
# 3252    28  Февраль  воскресенье      Задняя     Т237ВВ750         9380.0
# 3253    28  Февраль  воскресенье      Задняя      Т551РС69        21960.0
#
#        size_of_trash     density  tmax  tmin  taverage
# index
# ...

# %%
bd[bd['mounth'] == 'Февраль'][bd['day'] == 12]
# Out:
# /var/folders/85/nvry22pd6nx6pfd1c1h6z_nr0000gp/T/ipykernel_80750/1762628267.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   bd[bd['mounth'] == 'Февраль'][bd['day'] == 12]
#        day   mounth day_of_week type_of_car number_of_car  mass_of_trash  \
# index
# 2302    12  Февраль     пятница  Бункеровоз     В297КЕ147         3780.0
# 2303    12  Февраль     пятница  Бункеровоз     К721ВС154         3720.0
# 2304    12  Февраль     пятница  Бункеровоз     Н726РУ154         2840.0
# 2305    12  Февраль     пятница  Бункеровоз     Н991НУ154         3160.0
# 2307    12  Февраль     пятница  Мультилифт     Н869МК154         3480.0
# 2308    12  Февраль     пятница    Самосвал     В149НА750         1900.0
# 2309    12  Февраль     пятница    Самосвал     К693СА154         1640.0
# 2310    12  Февраль     пятница    Самосвал     К722ВС154         3320.0
# 2311    12  Февраль     пятница    Самосвал     К836ВС154         1380.0
# ...

# %%
bd[bd['type_of_car'] == 'Бункеровоз'][bd['mounth'] == 'Май']
# Out:
# /var/folders/85/nvry22pd6nx6pfd1c1h6z_nr0000gp/T/ipykernel_80750/3375056235.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   bd[bd['type_of_car'] == 'Бункеровоз'][bd['mounth'] == 'Май']
#        day mounth  day_of_week type_of_car number_of_car  mass_of_trash  \
# index
# 6392     1    Май      суббота  Бункеровоз     В297КЕ147         6160.0
# 6393     1    Май      суббота  Бункеровоз     К721ВС154         5780.0
# 6394     1    Май      суббота  Бункеровоз     Н726РУ154         8900.0
# 6395     1    Май      суббота  Бункеровоз     Н991НУ154         4100.0
# 6455     2    Май  воскресенье  Бункеровоз     В297КЕ147         8040.0
# ...    ...    ...          ...         ...           ...            ...
# 8222    30    Май  воскресенье  Бункеровоз     Н991НУ154         4640.0
# 8282    31    Май  понедельник  Бункеровоз     В297КЕ147         5200.0
# 8283    31    Май  понедельник  Бункеровоз     К721ВС154         5560.0
# ...

# %%
bd[bd['type_of_car'] == 'Бункеровоз'][bd['number_of_car'].isin(["Н726РУ154", "Н991НУ154"])]
# Out:
# /var/folders/85/nvry22pd6nx6pfd1c1h6z_nr0000gp/T/ipykernel_80750/2677617504.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   bd[bd['type_of_car'] == 'Бункеровоз'][bd['number_of_car'].isin(["Н726РУ154", "Н991НУ154"])]
#        day   mounth  day_of_week type_of_car number_of_car  mass_of_trash  \
# index
# 2        1   Январь      пятница  Бункеровоз     Н726РУ154         5400.0
# 3        1   Январь      пятница  Бункеровоз     Н991НУ154         4960.0
# 60       2   Январь      суббота  Бункеровоз     Н726РУ154         3880.0
# 61       2   Январь      суббота  Бункеровоз     Н991НУ154         3040.0
# 118      3   Январь  воскресенье  Бункеровоз     Н726РУ154         1540.0
# ...    ...      ...          ...         ...           ...            ...
# 20879   29  Декабрь        среда  Бункеровоз     Н991НУ154         2720.0
# 20940   30  Декабрь      четверг  Бункеровоз     Н726РУ154         3740.0
# ...

# %%
#TODO посмотреть то же для других машин

# %%
bd['type_of_car'].unique()
# Out:
# array(['Бункеровоз', 'Мультилифт', 'Самосвал', 'Грузовая', 'Фусо',
#        'Боковая', 'Задняя', 'КМУ'], dtype=object)

# %%
bd[bd['mounth'] == 'Январь']
# Out:
#       day  mounth  day_of_week type_of_car number_of_car  mass_of_trash  \
# 0       1  Январь      пятница  Бункеровоз     В297КЕ147         4300.0
# 1       1  Январь      пятница  Бункеровоз     К721ВС154         5180.0
# 2       1  Январь      пятница  Бункеровоз     Н726РУ154         5400.0
# 3       1  Январь      пятница  Бункеровоз     Н991НУ154         4960.0
# 4       1  Январь      пятница  Мультилифт     К801ВА154         3220.0
# ...   ...     ...          ...         ...           ...            ...
# 1791   31  Январь  воскресенье      Задняя     Н513ТТ154        15400.0
# 1792   31  Январь  воскресенье      Задняя     Н548ТТ154         8980.0
# 1794   31  Январь  воскресенье      Задняя     Н864ТТ154        19480.0
# 1795   31  Январь  воскресенье      Задняя     О369АР750        24360.0
# 1797   31  Январь  воскресенье      Задняя      Т551РС69        23160.0
#
#       size_of_trash     density  tmin  tmax  taverage
# ...

# %%
bd[bd['mounth'] == 'Январь']
# Out:
#       day  mounth  day_of_week type_of_car number_of_car  mass_of_trash  \
# 0       1  Январь      пятница  Бункеровоз     В297КЕ147         4300.0
# 1       1  Январь      пятница  Бункеровоз     К721ВС154         5180.0
# 2       1  Январь      пятница  Бункеровоз     Н726РУ154         5400.0
# 3       1  Январь      пятница  Бункеровоз     Н991НУ154         4960.0
# 4       1  Январь      пятница  Мультилифт     К801ВА154         3220.0
# ...   ...     ...          ...         ...           ...            ...
# 1791   31  Январь  воскресенье      Задняя     Н513ТТ154        15400.0
# 1792   31  Январь  воскресенье      Задняя     Н548ТТ154         8980.0
# 1794   31  Январь  воскресенье      Задняя     Н864ТТ154        19480.0
# 1795   31  Январь  воскресенье      Задняя     О369АР750        24360.0
# 1797   31  Январь  воскресенье      Задняя      Т551РС69        23160.0
#
#       size_of_trash     density  tmin  tmax  taverage
# ...

# %%
bd['number_of_car'] = bd['number_of_car'].str.replace(' ', '')

# %%
bd = bd[bd['mass_of_trash'] < 32480][bd['density'] < 294]
# Out:
# /var/folders/85/nvry22pd6nx6pfd1c1h6z_nr0000gp/T/ipykernel_9158/1967182555.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   bd = bd[bd['mass_of_trash'] < 32480][bd['density'] < 294]

# %%
bd[bd['type_of_car'] == 'Мультилифт']['number_of_car'].unique()
# Out:
# array(['К801ВА154', 'Н869МК154', 'Н416НС154'], dtype=object)

# %%
bd[bd['number_of_car'].isin(['К801ВА154', 'Н869МК154', 'Н416НС154'])][bd['mounth'] == 'Январь']
# Out:
# /var/folders/85/nvry22pd6nx6pfd1c1h6z_nr0000gp/T/ipykernel_80750/2591896185.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   bd[bd['number_of_car'].isin(['К801ВА154', 'Н869МК154', 'Н416НС154'])][bd['mounth'] == 'Январь']
#       day  mounth  day_of_week type_of_car number_of_car  mass_of_trash  \
# 4       1  Январь      пятница  Мультилифт     К801ВА154         3220.0
# 6       1  Январь      пятница  Мультилифт     Н869МК154         3140.0
# 62      2  Январь      суббота  Мультилифт     К801ВА154         2760.0
# 64      2  Январь      суббота  Мультилифт     Н869МК154         2700.0
# 120     3  Январь  воскресенье  Мультилифт     К801ВА154         3040.0
# ...   ...     ...          ...         ...           ...            ...
# 1686   30  Январь      суббота  Мультилифт     К801ВА154          740.0
# 1687   30  Январь      суббота  Мультилифт     Н416НС154         5740.0
# ...

# %%
bd[bd['mounth'] == 'Август']
# Out:
#        day  mounth  day_of_week type_of_car number_of_car  mass_of_trash  \
# 12363    1  Август  воскресенье  Бункеровоз     В297КЕ147         3460.0
# 12364    1  Август  воскресенье  Бункеровоз     К721ВС154         9660.0
# 12365    1  Август  воскресенье  Бункеровоз     Н726РУ154         5820.0
# 12366    1  Август  воскресенье  Бункеровоз     Н991НУ154         3860.0
# 12367    1  Август  воскресенье  Мультилифт     К801ВА154         2840.0
# ...    ...     ...          ...         ...           ...            ...
# 14185   31  Август      вторник      Задняя     Н548ТТ154        16060.0
# 14186   31  Август      вторник      Задняя     Н590ТТ154        13480.0
# 14187   31  Август      вторник      Задняя     Н864ТТ154        17020.0
# 14190   31  Август      вторник      Задняя     Т237ВВ750        13660.0
# 14191   31  Август      вторник      Задняя      Т551РС69        30500.0
#
#        size_of_trash     density  tmin  tmax  taverage
# ...

# %%
first = bd[bd['mounth'] == 'Ноябрь'][bd['day'] >= 1][bd['day'] <= 7]
pivot = first.pivot_table(index='day', values=['mass_of_trash', 'size_of_trash'], aggfunc='sum', sort=False)
pivot['density'] = pivot['mass_of_trash'] / pivot['size_of_trash']
pivot
# Out:
# /var/folders/85/nvry22pd6nx6pfd1c1h6z_nr0000gp/T/ipykernel_22804/2819094964.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   first = bd[bd['mounth'] == 'Ноябрь'][bd['day'] >= 1][bd['day'] <= 7]
# /var/folders/85/nvry22pd6nx6pfd1c1h6z_nr0000gp/T/ipykernel_22804/2819094964.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   first = bd[bd['mounth'] == 'Ноябрь'][bd['day'] >= 1][bd['day'] <= 7]
#      mass_of_trash  size_of_trash    density
# day
# 1         493200.0        5232.51  94.256867
# 2         466880.0        5764.02  80.999025
# 3         490040.0        6346.68  77.212023
# 4         417440.0        6080.15  68.656201
# 5         489140.0        6168.66  79.294369
# 6         487980.0        5678.53  85.934212
# 7         490560.0        5444.91  90.095153

# %%
bd[bd['mounth'] == 'Апрель'][bd['day'] == 1]
# Out:
# /var/folders/85/nvry22pd6nx6pfd1c1h6z_nr0000gp/T/ipykernel_80750/882384601.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   bd[bd['mounth'] == 'Апрель'][bd['day'] == 1]
#       day  mounth day_of_week type_of_car number_of_car  mass_of_trash  \
# 5040    1  Апрель     четверг  Бункеровоз     В297КЕ147         5220.0
# 5041    1  Апрель     четверг  Бункеровоз     К721ВС154         6380.0
# 5042    1  Апрель     четверг  Бункеровоз     Н726РУ154         5460.0
# 5043    1  Апрель     четверг  Бункеровоз     Н991НУ154         4500.0
# 5045    1  Апрель     четверг  Мультилифт     Н416НС154        12860.0
# 5046    1  Апрель     четверг  Мультилифт     Н869МК154         5200.0
# 5049    1  Апрель     четверг    Самосвал     К693СА154          980.0
# 5050    1  Апрель     четверг    Самосвал     К722ВС154         1500.0
# 5051    1  Апрель     четверг    Самосвал     К836ВС154         2220.0
# ...

# %%
bd = bd.drop('perehod_cherez_null', axis=1)

# %%
bd[bd['density'] > 140.625]
# Out:
#        day   mounth  day_of_week type_of_car number_of_car  mass_of_trash  \
# 69       2   Январь      суббота    Самосвал     Н200НХ154         2520.0
# 81       2   Январь      суббота    Самосвал     Н587ТТ154         1580.0
# 133      3   Январь  воскресенье    Грузовая     Н419РК154         3300.0
# 185      4   Январь  понедельник    Самосвал     Н200НХ154         4440.0
# 188      4   Январь  понедельник    Грузовая     Н344РТ154         4600.0
# ...    ...      ...          ...         ...           ...            ...
# 21333   31  Декабрь      пятница  Мультилифт     Н416НС154         6800.0
# 21340   31  Декабрь      пятница    Самосвал     Н283УУ154         1860.0
# 21341   31  Декабрь      пятница    Самосвал     Н300УУ154         4960.0
# 21343   31  Декабрь      пятница    Самосвал     Н576ТТ154         1620.0
# 21353   31  Декабрь      пятница    Грузовая     Н515РТ154         2540.0
#
#        size_of_trash     density  tmin  tmax  taverage  perehod_cherez_null
# ...

# %%
bd[bd['mass_of_trash'] > 14420]['type_of_car'].unique()
# Out:
# array(['Задняя', 'Фусо', 'КМУ', 'Самосвал', 'Бункеровоз', 'Мультилифт',
#        'Грузовая'], dtype=object)

# %%
def null_or_one(x):
    if x['density'] > np.percentile(bd['density'].dropna(), 75):
        return 1
    else:
        return 0
bd['75percentile'] = 0
bd['75percentile'] = bd.apply(lambda x: null_or_one(x), axis=1)
bd
# Out:
#        day   mounth day_of_week type_of_car number_of_car  mass_of_trash  \
# 0        1   Январь     пятница  Бункеровоз     В297КЕ147         4300.0
# 1        1   Январь     пятница  Бункеровоз     К721ВС154         5180.0
# 2        1   Январь     пятница  Бункеровоз     Н726РУ154         5400.0
# 3        1   Январь     пятница  Бункеровоз     Н991НУ154         4960.0
# 4        1   Январь     пятница  Мультилифт     К801ВА154         3220.0
# ...    ...      ...         ...         ...           ...            ...
# 21384   31  Декабрь     пятница      Задняя     Н590ТТ154        23140.0
# 21385   31  Декабрь     пятница      Задняя     Н864ТТ154        10660.0
# 21387   31  Декабрь     пятница      Задняя     Т237ВВ750        15940.0
# 21388   31  Декабрь     пятница      Задняя      Т551РС69        26920.0
# 21389   31  Декабрь     пятница      Задняя      Т799РС69         7300.0
#
#        size_of_trash     density  tmin  tmax  taverage  75percentile
# ...

# %%
onlyfloat = bd.drop(['mounth', 'day_of_week', 'type_of_car', 'number_of_car'], axis=1)
onlyfloat
# Out:
#        day  mass_of_trash  size_of_trash     density  tmin  tmax  taverage  \
# 0        1         4300.0          48.00   89.583333 -28.0 -32.0     -30.0
# 1        1         5180.0          40.00  129.500000 -28.0 -32.0     -30.0
# 2        1         5400.0          64.00   84.375000 -28.0 -32.0     -30.0
# 3        1         4960.0          48.00  103.333333 -28.0 -32.0     -30.0
# 4        1         3220.0          36.66   87.834152 -28.0 -32.0     -30.0
# ...    ...            ...            ...         ...   ...   ...       ...
# 21384   31        23140.0         286.27   80.832780 -16.0 -26.0     -21.0
# 21385   31        10660.0         152.41   69.942917 -16.0 -26.0     -21.0
# 21387   31        15940.0         228.20   69.851008 -16.0 -26.0     -21.0
# 21388   31        26920.0         332.20   81.035521 -16.0 -26.0     -21.0
# 21389   31         7300.0         158.78   45.975564 -16.0 -26.0     -21.0
#
#        perehod_cherez_null  temp
# 0                        0     0
# ...

# %%
onlyfloat.corr()
# Out:
#                           day  mass_of_trash  size_of_trash   density  \
# day                  1.000000      -0.006453      -0.004545 -0.004657
# mass_of_trash       -0.006453       1.000000       0.911992 -0.400688
# size_of_trash       -0.004545       0.911992       1.000000 -0.626733
# density             -0.004657      -0.400688      -0.626733  1.000000
# tmin                 0.008920       0.116513       0.028302  0.154364
# tmax                 0.015222       0.120797       0.027415  0.162128
# taverage             0.012027       0.119477       0.028092  0.159297
# perehod_cherez_null -0.015563       0.009781      -0.002712  0.012120
# temp                 0.033432       0.123433       0.032224  0.148497
#
#                          tmin      tmax  taverage  perehod_cherez_null  \
# day                  0.008920  0.015222  0.012027            -0.015563
# mass_of_trash        0.116513  0.120797  0.119477             0.009781
# ...

# %%
bd[bd['density'] > 200]
# Out:
#        day   mounth day_of_week type_of_car number_of_car  mass_of_trash  \
# 243      5   Январь     вторник    Самосвал     Н200НХ154         3760.0
# 295      6   Январь       среда  Мультилифт     Н416НС154         6740.0
# 314      6   Январь       среда    Самосвал     Н589ТТ154         7080.0
# 353      7   Январь     четверг  Мультилифт     Н416НС154         7100.0
# 431      8   Январь     пятница    Грузовая     Н833ТТ154         1720.0
# ...    ...      ...         ...         ...           ...            ...
# 21217   29  Декабрь       среда    Самосвал     Н300УУ154         7440.0
# 21229   29  Декабрь       среда    Грузовая     Н515РТ154         2260.0
# 21279   30  Декабрь     четверг    Самосвал     Н300УУ154         7420.0
# 21333   31  Декабрь     пятница  Мультилифт     Н416НС154         6800.0
# 21341   31  Декабрь     пятница    Самосвал     Н300УУ154         4960.0
#
#        size_of_trash     density  tmin  tmax  taverage  75percentile
# ...

# %%
bd[bd['mounth'].isin(['Январь', 'Февраль'])]
# Out:
#       day   mounth  day_of_week type_of_car number_of_car  mass_of_trash  \
# 0       1   Январь      пятница  Бункеровоз     В297КЕ147         4300.0
# 1       1   Январь      пятница  Бункеровоз     К721ВС154         5180.0
# 2       1   Январь      пятница  Бункеровоз     Н726РУ154         5400.0
# 3       1   Январь      пятница  Бункеровоз     Н991НУ154         4960.0
# 4       1   Январь      пятница  Мультилифт     К801ВА154         3220.0
# ...   ...      ...          ...         ...           ...            ...
# 3361   28  Февраль  воскресенье      Задняя     Н590ТТ154        20440.0
# 3362   28  Февраль  воскресенье      Задняя     Н864ТТ154        12360.0
# 3363   28  Февраль  воскресенье      Задняя     О369АР750        11420.0
# 3364   28  Февраль  воскресенье      Задняя     Т237ВВ750         9380.0
# 3365   28  Февраль  воскресенье      Задняя      Т551РС69        21960.0
#
#       size_of_trash     density  tmin  tmax  taverage  75percentile
# ...

# %%
bd['mass_of_trash'].sum()
# Out:
# 166000802.0

# %%
bd.pivot_table(index='mounth', values='mass_of_trash', aggfunc='sum', sort=False)
# Out:
#           mass_of_trash
# mounth
# Январь       12194712.0
# Февраль      10606932.0
# Март         12158740.0
# Апрель       13724800.0
# Май          15878320.0
# Июнь         14871071.0
# Июль         14262308.0
# Август       15544520.0
# Сентябрь     15316239.0
# Октябрь      15029407.0
# Ноябрь       13470460.0
# Декабрь      12943293.0

# %%
bd = bd.drop('baki', axis=1)

# %%
bd.pivot_table(index='mounth', values='size_of_trash', aggfunc='sum', sort=False)
# Out:
#           size_of_trash
# mounth
# Январь        178745.86
# Февраль       162563.33
# Март          172055.51
# Апрель        172174.06
# Май           191898.40
# Июнь          203197.81
# Июль          188280.39
# Август        180541.58
# Сентябрь      177157.01
# Октябрь       181272.84
# Ноябрь        173375.52
# Декабрь       184963.88

# %%
def null_or_one(x):
    if x['tmax'] < 0 and x['tmin'] > 0:
        return 1
    else:
        return 0
    
    
bd['perehod_cherez_null'] = 0
bd['perehod_cherez_null'] = bd.apply(lambda x: null_or_one(x), axis=1)
bd[bd['type_of_car'].isin(["Боковая", 'Задняя'])]
# Out:
#        day   mounth day_of_week type_of_car number_of_car  mass_of_trash  \
# 32       1   Январь     пятница     Боковая     В036АС147         1540.0
# 33       1   Январь     пятница     Боковая     Н403МВ154         3600.0
# 34       1   Январь     пятница     Боковая     Н405МВ154         3980.0
# 35       1   Январь     пятница      Задняя     К281ВС154        25020.0
# 37       1   Январь     пятница      Задняя     К910ЕА154        17840.0
# ...    ...      ...         ...         ...           ...            ...
# 21384   31  Декабрь     пятница      Задняя     Н590ТТ154        23140.0
# 21385   31  Декабрь     пятница      Задняя     Н864ТТ154        10660.0
# 21387   31  Декабрь     пятница      Задняя     Т237ВВ750        15940.0
# 21388   31  Декабрь     пятница      Задняя      Т551РС69        26920.0
# 21389   31  Декабрь     пятница      Задняя      Т799РС69         7300.0
#
#        size_of_trash     density  tmin  tmax  taverage  perehod_cherez_null  \
# ...

# %%
bd[bd['mass_of_trash'] > 3000][bd['mass_of_trash'] < 12000]
# Out:
# /var/folders/85/nvry22pd6nx6pfd1c1h6z_nr0000gp/T/ipykernel_9158/3337149926.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   bd[bd['mass_of_trash'] > 3000][bd['mass_of_trash'] < 12000]
#        day   mounth day_of_week type_of_car number_of_car  mass_of_trash  \
# 0        1   Январь     пятница  Бункеровоз     В297КЕ147         4300.0
# 1        1   Январь     пятница  Бункеровоз     К721ВС154         5180.0
# 2        1   Январь     пятница  Бункеровоз     Н726РУ154         5400.0
# 3        1   Январь     пятница  Бункеровоз     Н991НУ154         4960.0
# 4        1   Январь     пятница  Мультилифт     К801ВА154         3220.0
# ...    ...      ...         ...         ...           ...            ...
# 21364   31  Декабрь     пятница     Боковая     Н405МВ154         5700.0
# 21365   31  Декабрь     пятница      Задняя     В222СО178         6540.0
# 21372   31  Декабрь     пятница      Задняя     Н853НР123        10960.0
# ...

# %%
def temperatura(x):
    if x['taverage'] < 0:
        return 0
    else:
        return 1
bd['temp'] = 0
bd['temp'] = bd.apply(lambda x: temperatura(x), axis=1)
FataMorgana = bd[bd['perehod_cherez_null'] == 0].pivot_table(index='temp', values=['mass_of_trash', 'size_of_trash'], aggfunc='sum', sort=False)
FataMorgana['density'] = FataMorgana['mass_of_trash']/FataMorgana['size_of_trash']
FataMorgana
# Out:
#       mass_of_trash  size_of_trash    density
# temp
# 0        60282057.0      853958.72  70.591301
# 1        96987055.0     1179588.92  82.221063

# %%
TKO = np.percentile(bd[bd['type_of_car'].isin(["Фусо", "Задняя", "Боковая"])]["density"], 75)
STPONKA = np.percentile(bd[bd['type_of_car'].isin(["Бункеровоз", "Самосвал", "Грузовая", "Мультилифт"])]["density"], 25)
granitsa = (TKO + STPONKA) / 2
granitsa
# Out:
# 93.6699084725

# %%
bd.pivot_table(index='type_of_car', columns='mounth',  values='density', aggfunc='mean', sort=False)
# Out:
# mounth           Январь     Февраль        Март      Апрель         Май  \
# type_of_car
# Бункеровоз    86.541000   95.531714  113.896641  122.150426  139.295581
# Мультилифт   122.005023  139.011408  142.668123  134.338378  152.662836
# Самосвал     110.177665  115.552544  131.328760  143.159339  158.316332
# Грузовая     128.356976         NaN         NaN  155.762333         NaN
# Фусо          65.597718   61.252766   61.495734   71.432491   65.002086
# Боковая       68.290226   62.403538   67.015876   81.142718   92.689298
# Задняя        64.707214   61.384592   64.808059   72.740402   71.531066
# КМУ           38.165941   36.969852   41.738486   41.787895   38.803469
#
# mounth             Июнь        Июль      Август    Сентябрь     Октябрь  \
# type_of_car
# Бункеровоз   121.712277  121.804827  126.067146  134.969335  131.515730
# Мультилифт   146.463886  146.402614  155.257335  153.313708  136.896026
# Самосвал     144.439668  150.678936  156.744593  157.386435  150.225358
# ...

# %%
bd = bd.drop('perehod_cherez_null', axis=1)

# %%
bd = bd[bd['number_of_car'] != 'Н416НС154']

# %%
bd
# Out:
#        day   mounth day_of_week type_of_car number_of_car  mass_of_trash  \
# 0        1   Январь     пятница  Бункеровоз     В297КЕ147         4300.0
# 1        1   Январь     пятница  Бункеровоз     К721ВС154         5180.0
# 2        1   Январь     пятница  Бункеровоз     Н726РУ154         5400.0
# 3        1   Январь     пятница  Бункеровоз     Н991НУ154         4960.0
# 4        1   Январь     пятница  Мультилифт     К801ВА154         3220.0
# ...    ...      ...         ...         ...           ...            ...
# 21384   31  Декабрь     пятница      Задняя     Н590ТТ154        23140.0
# 21385   31  Декабрь     пятница      Задняя     Н864ТТ154        10660.0
# 21387   31  Декабрь     пятница      Задняя     Т237ВВ750        15940.0
# 21388   31  Декабрь     пятница      Задняя      Т551РС69        26920.0
# 21389   31  Декабрь     пятница      Задняя      Т799РС69         7300.0
#
#        size_of_trash     density  tmin  tmax  taverage
# ...

# %%
bd['size'] = bd['size_of_trash']*77.42
bd
# Out:
#        day   mounth day_of_week type_of_car number_of_car  mass_of_trash  \
# 0        1   Январь     пятница  Бункеровоз     В297КЕ147         4300.0
# 1        1   Январь     пятница  Бункеровоз     К721ВС154         5180.0
# 2        1   Январь     пятница  Бункеровоз     Н726РУ154         5400.0
# 3        1   Январь     пятница  Бункеровоз     Н991НУ154         4960.0
# 4        1   Январь     пятница  Мультилифт     К801ВА154         3220.0
# ...    ...      ...         ...         ...           ...            ...
# 21384   31  Декабрь     пятница      Задняя     Н590ТТ154        23140.0
# 21385   31  Декабрь     пятница      Задняя     Н864ТТ154        10660.0
# 21387   31  Декабрь     пятница      Задняя     Т237ВВ750        15940.0
# 21388   31  Декабрь     пятница      Задняя      Т551РС69        26920.0
# 21389   31  Декабрь     пятница      Задняя      Т799РС69         7300.0
#
#        size_of_trash     density  tmin  tmax  taverage        size
# ...

# %%
first = bd[bd['day'] <= 10][bd['day'] >= 6][bd['mounth'] == 'Март']
first
# second = bd[bd['day'] >= 1][bd['mounth'] == 'Март']
# pd.concat([second, first])
# Out:
# /var/folders/85/nvry22pd6nx6pfd1c1h6z_nr0000gp/T/ipykernel_9158/914752587.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   first = bd[bd['day'] <= 10][bd['day'] >= 6][bd['mounth'] == 'Март']
# /var/folders/85/nvry22pd6nx6pfd1c1h6z_nr0000gp/T/ipykernel_9158/914752587.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   first = bd[bd['day'] <= 10][bd['day'] >= 6][bd['mounth'] == 'Март']
#       day mounth day_of_week type_of_car number_of_car  mass_of_trash  \
# 3636    6   Март     суббота  Бункеровоз     В297КЕ147         3580.0
# 3637    6   Март     суббота  Бункеровоз     К721ВС154         4200.0
# 3639    6   Март     суббота  Бункеровоз     Н991НУ154         4960.0
# 3642    6   Март     суббота  Мультилифт     Н869МК154         5340.0
# 3644    6   Март     суббота    Самосвал     К693СА154         1260.0
# ...   ...    ...         ...         ...           ...            ...
# ...

# %%
bd
# Out:
#        day   mounth day_of_week type_of_car number_of_car  mass_of_trash  \
# 0        1   Январь     пятница  Бункеровоз     В297КЕ147         4300.0
# 1        1   Январь     пятница  Бункеровоз     К721ВС154         5180.0
# 2        1   Январь     пятница  Бункеровоз     Н726РУ154         5400.0
# 3        1   Январь     пятница  Бункеровоз     Н991НУ154         4960.0
# 4        1   Январь     пятница  Мультилифт     К801ВА154         3220.0
# ...    ...      ...         ...         ...           ...            ...
# 21384   31  Декабрь     пятница      Задняя     Н590ТТ154        23140.0
# 21385   31  Декабрь     пятница      Задняя     Н864ТТ154        10660.0
# 21387   31  Декабрь     пятница      Задняя     Т237ВВ750        15940.0
# 21388   31  Декабрь     пятница      Задняя      Т551РС69        26920.0
# 21389   31  Декабрь     пятница      Задняя      Т799РС69         7300.0
#
#        size_of_trash     density  tmin  tmax  taverage
# ...

# %%
bd[bd['type_of_car'].isin(["Фусо", "Задняя", "Боковая"])]["density"].mean()
# Out:
# 72.66059368897433

# %%
bd[bd['type_of_car'].isin(["Бункеровоз", "Мультлифт", "Самосвал", "Грузовая"])]["density"].mean()
# Out:
# 139.0009231756849

# %%
bd['size'] = bd['size_of_trash'] * 77.48
bd
# Out:
#        day   mounth day_of_week type_of_car number_of_car  mass_of_trash  \
# 0        1   Январь     пятница  Бункеровоз     В297КЕ147         4300.0
# 1        1   Январь     пятница  Бункеровоз     К721ВС154         5180.0
# 2        1   Январь     пятница  Бункеровоз     Н726РУ154         5400.0
# 3        1   Январь     пятница  Бункеровоз     Н991НУ154         4960.0
# 4        1   Январь     пятница  Мультилифт     К801ВА154         3220.0
# ...    ...      ...         ...         ...           ...            ...
# 21384   31  Декабрь     пятница      Задняя     Н590ТТ154        23140.0
# 21385   31  Декабрь     пятница      Задняя     Н864ТТ154        10660.0
# 21387   31  Декабрь     пятница      Задняя     Т237ВВ750        15940.0
# 21388   31  Декабрь     пятница      Задняя      Т551РС69        26920.0
# 21389   31  Декабрь     пятница      Задняя      Т799РС69         7300.0
#
#        size_of_trash     density  tmin  tmax  taverage        size
# ...

# %%
fu = bd.pivot_table(index='mounth', values=['mass_of_trash', 'size_of_trash'], aggfunc='sum', sort=False)

# %%
fu['density'] = fu['mass_of_trash'] / fu['size_of_trash']
fu
# Out:
#           mass_of_trash  size_of_trash    density
# mounth
# Январь       12695192.0      183915.96  69.027136
# Февраль      10989042.0      166616.31  65.954179
# Март         12583040.0      176758.84  71.187614
# Апрель       14441800.0      179304.94  80.543235
# Май          16471120.0      196956.12  83.628374
# Июнь         15530401.0      207571.52  74.819518
# Июль         14801168.0      193023.71  76.680569
# Август       16803720.0      195605.24  85.906288
# Сентябрь     16746419.0      190716.93  87.807721
# Октябрь      16187987.0      193057.50  83.850599
# Ноябрь       14263160.0      180762.27  78.905626
# Декабрь      13058013.0      185312.88  70.464681

# %%
nazvanie = bd.pivot_table(index='type_of_car', columns='perehod_cherez_null', values=['mass_of_trash', 'size_of_trash'], aggfunc='sum', sort=False)
nazvanie
# Out:
#                     mass_of_trash             size_of_trash
# perehod_cherez_null             0           1             0          1
# type_of_car
# Бункеровоз              7106701.0    799960.0      57990.50    6241.00
# Мультилифт              4161040.0    381270.0      27324.15    2706.50
# Самосвал               23456154.0   2374820.0     165851.30   16795.22
# Грузовая                1791472.0    340440.0      13190.37    2338.83
# Фусо                    2422520.0    241520.0      38707.87    3608.07
# Боковая                 4527982.0    528280.0      56734.90    6306.14
# Задняя                110486943.0  12275520.0    1595295.35  169839.91
# КМУ                     3316300.0    360140.0      78453.20    8218.91

# %%
bd.head()
# Out:
#    day  mounth day_of_week type_of_car number_of_car  mass_of_trash  \
# 0    1  Январь     пятница  Бункеровоз     В297КЕ147         4300.0
# 1    1  Январь     пятница  Бункеровоз     К721ВС154         5180.0
# 2    1  Январь     пятница  Бункеровоз     Н726РУ154         5400.0
# 3    1  Январь     пятница  Бункеровоз     Н991НУ154         4960.0
# 4    1  Январь     пятница  Мультилифт     К801ВА154         3220.0
#
#    size_of_trash     density  tmin  tmax  taverage
# 0          48.00   89.583333 -28.0 -32.0     -30.0
# 1          40.00  129.500000 -28.0 -32.0     -30.0
# 2          64.00   84.375000 -28.0 -32.0     -30.0
# 3          48.00  103.333333 -28.0 -32.0     -30.0
# 4          36.66   87.834152 -28.0 -32.0     -30.0

# %%
bd['mass_of_trash'].sum()/bd['size_of_trash'].sum()
# Out:
# 77.41590304254244

# %%
bd[bd['mounth'] == 'Ноябрь'][bd['day'] == 3]['mass_of_trash'].sum()/bd[bd['mounth'] == 'Ноябрь'][bd['day'] == 3]['size_of_trash'].sum() - bd[bd['mounth'] == 'Ноябрь'][bd['day'] == 4]['mass_of_trash'].sum()/bd[bd['mounth'] == 'Ноябрь'][bd['day'] == 4]['size_of_trash'].sum()
# Out:
# /var/folders/85/nvry22pd6nx6pfd1c1h6z_nr0000gp/T/ipykernel_26740/4252560074.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   bd[bd['mounth'] == 'Ноябрь'][bd['day'] == 3]['mass_of_trash'].sum()/bd[bd['mounth'] == 'Ноябрь'][bd['day'] == 3]['size_of_trash'].sum() - bd[bd['mounth'] == 'Ноябрь'][bd['day'] == 4]['mass_of_trash'].sum()/bd[bd['mounth'] == 'Ноябрь'][bd['day'] == 4]['size_of_trash'].sum()
# /var/folders/85/nvry22pd6nx6pfd1c1h6z_nr0000gp/T/ipykernel_26740/4252560074.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   bd[bd['mounth'] == 'Ноябрь'][bd['day'] == 3]['mass_of_trash'].sum()/bd[bd['mounth'] == 'Ноябрь'][bd['day'] == 3]['size_of_trash'].sum() - bd[bd['mounth'] == 'Ноябрь'][bd['day'] == 4]['mass_of_trash'].sum()/bd[bd['mounth'] == 'Ноябрь'][bd['day'] == 4]['size_of_trash'].sum()
# ...

# %%
bd[bd['type_of_car'].isin(['Фусо', 'Задняя', 'Боковая'])]['mass_of_trash'].sum()/bd[bd['type_of_car'].isin(['Фусо', 'Задняя', 'Боковая'])]['size_of_trash'].sum()
# Out:
# 69.521421096139

# %%
bd[bd['type_of_car'].isin(['Бункеровоз', 'Мультилифт', 'Самосвал', 'Грузовая'])]['mass_of_trash'].sum()/bd[bd['type_of_car'].isin(['Бункеровоз', 'Мультилифт', 'Самосвал', 'Грузовая'])]['size_of_trash'].sum()
# Out:
# 137.98923991441563
