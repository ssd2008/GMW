# %%
import pandas as pd
import numpy as np

# %%
bd = pd.read_csv('Копия_base_test.xlsx - weather.csv')

# %%
bd
# Out:
#        day   mounth day_of_week type_of_car number_of_car  mass_of_trash  \
# 0        1   Январь     пятница  Бункеровоз     В297КЕ147         4300.0
# 1        1   Январь     пятница  Бункеровоз     К721ВС154         5180.0
# 2        1   Январь     пятница  Бункеровоз     Н726РУ154         5400.0
# 3        1   Январь     пятница  Бункеровоз     Н991НУ154         4960.0
# 4        1   Январь     пятница  Мультилифт     К801ВА154         3220.0
# ...    ...      ...         ...         ...           ...            ...
# 21384   31  Декабрь     пятница      Задняя     Н590ТТ154        23140.0
# 21385   31  Декабрь     пятница      Задняя     Н864ТТ154        10660.0
# 21387   31  Декабрь     пятница      Задняя     Т237ВВ750        15940.0
# 21388   31  Декабрь     пятница      Задняя      Т551РС69        26920.0
# 21389   31  Декабрь     пятница      Задняя      Т799РС69         7300.0
#
#        size_of_trash     density  tmin  tmax  taverage
# ...

# %%
bd['type_of_car'] = bd['type_of_car'].str.replace('ФУСО', 'Фусо')
bd['type_of_car'] = bd['type_of_car'].str.replace('боковая', 'Боковая')
bd['type_of_car'] = bd['type_of_car'].str.replace('бункеровоз', 'Бункеровоз')
bd['type_of_car'] = bd['type_of_car'].str.replace('задняя', 'Задняя')
bd['type_of_car'] = bd['type_of_car'].str.replace('кму', 'КМУ')
bd['type_of_car'] = bd['type_of_car'].str.replace('мультилифт', 'Мультилифт')
bd['type_of_car'] = bd['type_of_car'].str.replace('самосвал', 'Самосвал')
bd['type_of_car'] = bd['type_of_car'].str.replace('фусо', 'Фусо')
bd.head()
# Out:
#    day  mounth day_of_week type_of_car number_of_car mass_of_trash  \
# 0    1  Январь     пятница  Бункеровоз     В297КЕ147          4300
# 1    1  Январь     пятница  Бункеровоз     К721ВС154          5180
# 2    1  Январь     пятница  Бункеровоз     Н726РУ154          5400
# 3    1  Январь     пятница  Бункеровоз     Н991НУ154          4960
# 4    1  Январь     пятница  Мультилифт     К801ВА154          3220
#
#   size_of_trash      density  tmin  tmax
# 0            48  89,58333333  -28°  -32°
# 1            40        129,5  -28°  -32°
# 2            64       84,375  -28°  -32°
# 3            48  103,3333333  -28°  -32°
# 4         36,66  87,83415166  -28°  -32°

# %%
bd = bd[bd['size_of_trash'] != '0']
bd = bd[bd['mass_of_trash'] != '0']
bd = bd[bd['mass_of_trash'] != '-']
bd['mass_of_trash'] = bd['mass_of_trash'].str.replace(' ', '').str.replace(',', '.').astype(float)
bd['size_of_trash'] = bd['size_of_trash'].str.replace(' ', '').str.replace(',', '.').astype(float)
bd['density'] = bd['density'].str.replace(' ', '').str.replace(',', '.').astype(float)
bd['tmin'] = bd['tmin'].str.replace('°', '').astype(float)
bd['tmax'] = bd['tmax'].str.replace('°', '').astype(float)
bd['taverage'] = (bd['tmax'] + bd['tmin']) / 2
bd.head()
# Out:
#    day  mounth day_of_week type_of_car number_of_car  mass_of_trash  \
# 0    1  Январь     пятница  Бункеровоз     В297КЕ147         4300.0
# 1    1  Январь     пятница  Бункеровоз     К721ВС154         5180.0
# 2    1  Январь     пятница  Бункеровоз     Н726РУ154         5400.0
# 3    1  Январь     пятница  Бункеровоз     Н991НУ154         4960.0
# 4    1  Январь     пятница  Мультилифт     К801ВА154         3220.0
#
#    size_of_trash     density  tmin  tmax  taverage
# 0          48.00   89.583333 -28.0 -32.0     -30.0
# 1          40.00  129.500000 -28.0 -32.0     -30.0
# 2          64.00   84.375000 -28.0 -32.0     -30.0
# 3          48.00  103.333333 -28.0 -32.0     -30.0
# 4          36.66   87.834152 -28.0 -32.0     -30.0

# %%
bd = bd[bd['density'] < 500]
bd
# Out:
#        day   mounth day_of_week type_of_car number_of_car  mass_of_trash  \
# 0        1   Январь     пятница  Бункеровоз     В297КЕ147         4300.0
# 1        1   Январь     пятница  Бункеровоз     К721ВС154         5180.0
# 2        1   Январь     пятница  Бункеровоз     Н726РУ154         5400.0
# 3        1   Январь     пятница  Бункеровоз     Н991НУ154         4960.0
# 4        1   Январь     пятница  Мультилифт     К801ВА154         3220.0
# ...    ...      ...         ...         ...           ...            ...
# 21384   31  Декабрь     пятница      Задняя     Н590ТТ154        23140.0
# 21385   31  Декабрь     пятница      Задняя     Н864ТТ154        10660.0
# 21387   31  Декабрь     пятница      Задняя     Т237ВВ750        15940.0
# 21388   31  Декабрь     пятница      Задняя      Т551РС69        26920.0
# 21389   31  Декабрь     пятница      Задняя      Т799РС69         7300.0
#
#        size_of_trash     density  tmin  tmax  taverage
# ...

# %%
bd[-15 < bd['taverage']][bd['taverage'] < 15]
# Out:
# /var/folders/85/nvry22pd6nx6pfd1c1h6z_nr0000gp/T/ipykernel_73109/2331445284.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   bd[-15 < bd['taverage']][bd['taverage'] < 15]
#        day   mounth  day_of_week type_of_car number_of_car  mass_of_trash  \
# index
# 928     17   Январь  воскресенье  Бункеровоз     В297КЕ147         3360.0
# 929     17   Январь  воскресенье  Бункеровоз     К721ВС154         5420.0
# 930     17   Январь  воскресенье  Бункеровоз     Н726РУ154         8840.0
# 931     17   Январь  воскресенье  Бункеровоз     Н991НУ154         5380.0
# 932     17   Январь  воскресенье  Мультилифт     К801ВА154         2240.0
# ...    ...      ...          ...         ...           ...            ...
# 20933   29  Декабрь        среда      Задняя     Н864ТТ154        11520.0
# 20934   29  Декабрь        среда      Задняя     О369АР750        13220.0
# 20935   29  Декабрь        среда      Задняя     Т237ВВ750        14440.0
# ...

# %%
p = np.percentile(bd['density'].dropna(), 75)
p
# Out:
# 140.625

# %%
p = np.percentile(bd['density'].dropna(), 25)
p
# Out:
# 66.2471755475

# %%
bd[bd['density'] < 140.625][bd['density'] > 66.2471755475]
# Out:
# /var/folders/85/nvry22pd6nx6pfd1c1h6z_nr0000gp/T/ipykernel_80750/3758260233.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   bd[bd['density'] < 140.625][bd['density'] > 66.2471755475]
#        day   mounth day_of_week type_of_car number_of_car  mass_of_trash  \
# 0        1   Январь     пятница  Бункеровоз     В297КЕ147         4300.0
# 1        1   Январь     пятница  Бункеровоз     К721ВС154         5180.0
# 2        1   Январь     пятница  Бункеровоз     Н726РУ154         5400.0
# 3        1   Январь     пятница  Бункеровоз     Н991НУ154         4960.0
# 4        1   Январь     пятница  Мультилифт     К801ВА154         3220.0
# ...    ...      ...         ...         ...           ...            ...
# 21383   31  Декабрь     пятница      Задняя     Н513ТТ154        21200.0
# 21384   31  Декабрь     пятница      Задняя     Н590ТТ154        23140.0
# 21385   31  Декабрь     пятница      Задняя     Н864ТТ154        10660.0
# ...

# %%
df = bd.copy()
mask = df[df['tmin'] < 0][df['tmax'] > 0]['taverage']
df.loc[mask, 'perehod_cherez_null'] = 1
df
# Out:
# /var/folders/85/nvry22pd6nx6pfd1c1h6z_nr0000gp/T/ipykernel_80750/2760853924.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   mask = df[df['tmin'] < 0][df['tmax'] > 0]['taverage'].str.startswith('0')
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[159], line 2
#       1 df = bd.copy()
# ----> 2 mask = df[df['tmin'] < 0][df['tmax'] > 0]['taverage'].str.startswith('0')
#       3 df.loc[mask, 'perehod_cherez_null'] = 1
#       4 df
#
# File ~/environments/lib/python3.9/site-packages/pandas/core/generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# ...

# %%
day_in_mounths = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]
day_by_mounths = {"Январь": 0, "Февраль": 31, "Март": 59, "Апрель": 90, "Май": 120, "Июнь": 151, "Июль": 181, "Август": 212, "Сентябрь": 243, "Октябрь": 273, "Ноябрь": 304, "Декабрь": 334}
bd['num_of_day'] = day_by_mounths[bd['mounth']] + bd['day']
bd['num_of_day']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[155], line 3
#       1 day_in_mounths = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]
#       2 day_by_mounths = {"Январь": 0, "Февраль": 31, "Март": 59, "Апрель": 90, "Май": 120, "Июнь": 151, "Июль": 181, "Август": 212, "Сентябрь": 243, "Октябрь": 273, "Ноябрь": 304, "Декабрь": 334}
# ----> 3 bd['num_of_day'] = day_by_mounths[bd['mounth']] + bd['day']
#       4 bd['num_of_day']
#
# TypeError: unhashable type: 'Series'

# %%
bd.to_excel('/Users/ssd/Downloads/BMM.xlsx')

# %%
bd[-25 < bd['taverage']][bd['taverage'] < 25]
# Out:
# /var/folders/85/nvry22pd6nx6pfd1c1h6z_nr0000gp/T/ipykernel_80750/2791028643.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   bd[-25 < bd['taverage']][bd['taverage'] < 25]
#        day   mounth day_of_week type_of_car number_of_car  mass_of_trash  \
# 348      7   Январь     четверг  Бункеровоз     В297КЕ147         4500.0
# 349      7   Январь     четверг  Бункеровоз     К721ВС154         3320.0
# 350      7   Январь     четверг  Бункеровоз     Н726РУ154         6580.0
# 351      7   Январь     четверг  Бункеровоз     Н991НУ154         3220.0
# 352      7   Январь     четверг  Мультилифт     К801ВА154         2640.0
# ...    ...      ...         ...         ...           ...            ...
# 21384   31  Декабрь     пятница      Задняя     Н590ТТ154        23140.0
# 21385   31  Декабрь     пятница      Задняя     Н864ТТ154        10660.0
# 21387   31  Декабрь     пятница      Задняя     Т237ВВ750        15940.0
# ...

# %%
bd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 bd
#
# NameError: name 'bd' is not defined

# %%
bd[bd['mounth'] == 'Февраль']
# Out:
#        day   mounth  day_of_week type_of_car number_of_car  mass_of_trash  \
# index
# 1798     1  Февраль  понедельник  Бункеровоз     В297КЕ147         3820.0
# 1799     1  Февраль  понедельник  Бункеровоз     К721ВС154         3740.0
# 1800     1  Февраль  понедельник  Бункеровоз     Н726РУ154         5180.0
# 1801     1  Февраль  понедельник  Бункеровоз     Н991НУ154         9700.0
# 1802     1  Февраль  понедельник  Мультилифт     Н416НС154         5620.0
# ...    ...      ...          ...         ...           ...            ...
# 3249    28  Февраль  воскресенье      Задняя     Н590ТТ154        20440.0
# 3250    28  Февраль  воскресенье      Задняя     Н864ТТ154        12360.0
# 3251    28  Февраль  воскресенье      Задняя     О369АР750        11420.0
# 3252    28  Февраль  воскресенье      Задняя     Т237ВВ750         9380.0
# 3253    28  Февраль  воскресенье      Задняя      Т551РС69        21960.0
#
#        size_of_trash     density  tmax  tmin  taverage
# index
# ...

# %%
bd[bd['mounth'] == 'Февраль'][bd['day'] == 12]
# Out:
# /var/folders/85/nvry22pd6nx6pfd1c1h6z_nr0000gp/T/ipykernel_80750/1762628267.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   bd[bd['mounth'] == 'Февраль'][bd['day'] == 12]
#        day   mounth day_of_week type_of_car number_of_car  mass_of_trash  \
# index
# 2302    12  Февраль     пятница  Бункеровоз     В297КЕ147         3780.0
# 2303    12  Февраль     пятница  Бункеровоз     К721ВС154         3720.0
# 2304    12  Февраль     пятница  Бункеровоз     Н726РУ154         2840.0
# 2305    12  Февраль     пятница  Бункеровоз     Н991НУ154         3160.0
# 2307    12  Февраль     пятница  Мультилифт     Н869МК154         3480.0
# 2308    12  Февраль     пятница    Самосвал     В149НА750         1900.0
# 2309    12  Февраль     пятница    Самосвал     К693СА154         1640.0
# 2310    12  Февраль     пятница    Самосвал     К722ВС154         3320.0
# 2311    12  Февраль     пятница    Самосвал     К836ВС154         1380.0
# ...

# %%
bd[bd['type_of_car'] == 'Бункеровоз'][bd['mounth'] == 'Май']
# Out:
# /var/folders/85/nvry22pd6nx6pfd1c1h6z_nr0000gp/T/ipykernel_80750/3375056235.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   bd[bd['type_of_car'] == 'Бункеровоз'][bd['mounth'] == 'Май']
#        day mounth  day_of_week type_of_car number_of_car  mass_of_trash  \
# index
# 6392     1    Май      суббота  Бункеровоз     В297КЕ147         6160.0
# 6393     1    Май      суббота  Бункеровоз     К721ВС154         5780.0
# 6394     1    Май      суббота  Бункеровоз     Н726РУ154         8900.0
# 6395     1    Май      суббота  Бункеровоз     Н991НУ154         4100.0
# 6455     2    Май  воскресенье  Бункеровоз     В297КЕ147         8040.0
# ...    ...    ...          ...         ...           ...            ...
# 8222    30    Май  воскресенье  Бункеровоз     Н991НУ154         4640.0
# 8282    31    Май  понедельник  Бункеровоз     В297КЕ147         5200.0
# 8283    31    Май  понедельник  Бункеровоз     К721ВС154         5560.0
# ...

# %%
bd[bd['type_of_car'] == 'Бункеровоз'][bd['number_of_car'].isin(["Н726РУ154", "Н991НУ154"])]
# Out:
# /var/folders/85/nvry22pd6nx6pfd1c1h6z_nr0000gp/T/ipykernel_80750/2677617504.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   bd[bd['type_of_car'] == 'Бункеровоз'][bd['number_of_car'].isin(["Н726РУ154", "Н991НУ154"])]
#        day   mounth  day_of_week type_of_car number_of_car  mass_of_trash  \
# index
# 2        1   Январь      пятница  Бункеровоз     Н726РУ154         5400.0
# 3        1   Январь      пятница  Бункеровоз     Н991НУ154         4960.0
# 60       2   Январь      суббота  Бункеровоз     Н726РУ154         3880.0
# 61       2   Январь      суббота  Бункеровоз     Н991НУ154         3040.0
# 118      3   Январь  воскресенье  Бункеровоз     Н726РУ154         1540.0
# ...    ...      ...          ...         ...           ...            ...
# 20879   29  Декабрь        среда  Бункеровоз     Н991НУ154         2720.0
# 20940   30  Декабрь      четверг  Бункеровоз     Н726РУ154         3740.0
# ...

# %%
#TODO посмотреть то же для других машин

# %%
bd['type_of_car'].unique()
# Out:
# array(['Бункеровоз', 'Мультилифт', 'Самосвал', 'Грузовая', 'Фусо',
#        'Боковая', 'Задняя', 'КМУ'], dtype=object)

# %%
bd[bd['mounth'] == 'Январь']
# Out:
#       day  mounth  day_of_week type_of_car number_of_car  mass_of_trash  \
# 0       1  Январь      пятница  Бункеровоз     В297КЕ147         4300.0
# 1       1  Январь      пятница  Бункеровоз     К721ВС154         5180.0
# 2       1  Январь      пятница  Бункеровоз     Н726РУ154         5400.0
# 3       1  Январь      пятница  Бункеровоз     Н991НУ154         4960.0
# 4       1  Январь      пятница  Мультилифт     К801ВА154         3220.0
# ...   ...     ...          ...         ...           ...            ...
# 1791   31  Январь  воскресенье      Задняя     Н513ТТ154        15400.0
# 1792   31  Январь  воскресенье      Задняя     Н548ТТ154         8980.0
# 1794   31  Январь  воскресенье      Задняя     Н864ТТ154        19480.0
# 1795   31  Январь  воскресенье      Задняя     О369АР750        24360.0
# 1797   31  Январь  воскресенье      Задняя      Т551РС69        23160.0
#
#       size_of_trash     density  tmin  tmax  taverage
# ...

# %%
bd[bd['mounth'] == 'Январь']
# Out:
#       day  mounth  day_of_week type_of_car number_of_car  mass_of_trash  \
# 0       1  Январь      пятница  Бункеровоз     В297КЕ147         4300.0
# 1       1  Январь      пятница  Бункеровоз     К721ВС154         5180.0
# 2       1  Январь      пятница  Бункеровоз     Н726РУ154         5400.0
# 3       1  Январь      пятница  Бункеровоз     Н991НУ154         4960.0
# 4       1  Январь      пятница  Мультилифт     К801ВА154         3220.0
# ...   ...     ...          ...         ...           ...            ...
# 1791   31  Январь  воскресенье      Задняя     Н513ТТ154        15400.0
# 1792   31  Январь  воскресенье      Задняя     Н548ТТ154         8980.0
# 1794   31  Январь  воскресенье      Задняя     Н864ТТ154        19480.0
# 1795   31  Январь  воскресенье      Задняя     О369АР750        24360.0
# 1797   31  Январь  воскресенье      Задняя      Т551РС69        23160.0
#
#       size_of_trash     density  tmin  tmax  taverage
# ...

# %%
bd['number_of_car'] = bd['number_of_car'].str.replace(' ', '')

# %%
bd[bd['type_of_car'] == 'Мультилифт']['number_of_car'].unique()
# Out:
# array(['К801ВА154', 'Н869МК154', 'Н416НС154'], dtype=object)

# %%
bd[bd['number_of_car'].isin(['К801ВА154', 'Н869МК154', 'Н416НС154'])][bd['mounth'] == 'Январь']
# Out:
# /var/folders/85/nvry22pd6nx6pfd1c1h6z_nr0000gp/T/ipykernel_80750/2591896185.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   bd[bd['number_of_car'].isin(['К801ВА154', 'Н869МК154', 'Н416НС154'])][bd['mounth'] == 'Январь']
#       day  mounth  day_of_week type_of_car number_of_car  mass_of_trash  \
# 4       1  Январь      пятница  Мультилифт     К801ВА154         3220.0
# 6       1  Январь      пятница  Мультилифт     Н869МК154         3140.0
# 62      2  Январь      суббота  Мультилифт     К801ВА154         2760.0
# 64      2  Январь      суббота  Мультилифт     Н869МК154         2700.0
# 120     3  Январь  воскресенье  Мультилифт     К801ВА154         3040.0
# ...   ...     ...          ...         ...           ...            ...
# 1686   30  Январь      суббота  Мультилифт     К801ВА154          740.0
# 1687   30  Январь      суббота  Мультилифт     Н416НС154         5740.0
# ...

# %%
bd[bd['mounth'] == 'Август']
# Out:
#        day  mounth  day_of_week type_of_car number_of_car  mass_of_trash  \
# 12363    1  Август  воскресенье  Бункеровоз     В297КЕ147         3460.0
# 12364    1  Август  воскресенье  Бункеровоз     К721ВС154         9660.0
# 12365    1  Август  воскресенье  Бункеровоз     Н726РУ154         5820.0
# 12366    1  Август  воскресенье  Бункеровоз     Н991НУ154         3860.0
# 12367    1  Август  воскресенье  Мультилифт     К801ВА154         2840.0
# ...    ...     ...          ...         ...           ...            ...
# 14185   31  Август      вторник      Задняя     Н548ТТ154        16060.0
# 14186   31  Август      вторник      Задняя     Н590ТТ154        13480.0
# 14187   31  Август      вторник      Задняя     Н864ТТ154        17020.0
# 14190   31  Август      вторник      Задняя     Т237ВВ750        13660.0
# 14191   31  Август      вторник      Задняя      Т551РС69        30500.0
#
#        size_of_trash     density  tmin  tmax  taverage
# ...

# %%
bd[bd['mounth'] == 'Апрель'][bd['day'] == 1]['density'].mean() - bd[bd['mounth'] == 'Март'][bd['day'] == 31]['density'].mean()
# Out:
# /var/folders/85/nvry22pd6nx6pfd1c1h6z_nr0000gp/T/ipykernel_80750/920578880.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   bd[bd['mounth'] == 'Апрель'][bd['day'] == 1]['density'].mean() - bd[bd['mounth'] == 'Март'][bd['day'] == 31]['density'].mean()
# /var/folders/85/nvry22pd6nx6pfd1c1h6z_nr0000gp/T/ipykernel_80750/920578880.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   bd[bd['mounth'] == 'Апрель'][bd['day'] == 1]['density'].mean() - bd[bd['mounth'] == 'Март'][bd['day'] == 31]['density'].mean()
# -21.389188595444438

# %%
bd[bd['mounth'] == 'Апрель'][bd['day'] == 1]
# Out:
# /var/folders/85/nvry22pd6nx6pfd1c1h6z_nr0000gp/T/ipykernel_80750/882384601.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   bd[bd['mounth'] == 'Апрель'][bd['day'] == 1]
#       day  mounth day_of_week type_of_car number_of_car  mass_of_trash  \
# 5040    1  Апрель     четверг  Бункеровоз     В297КЕ147         5220.0
# 5041    1  Апрель     четверг  Бункеровоз     К721ВС154         6380.0
# 5042    1  Апрель     четверг  Бункеровоз     Н726РУ154         5460.0
# 5043    1  Апрель     четверг  Бункеровоз     Н991НУ154         4500.0
# 5045    1  Апрель     четверг  Мультилифт     Н416НС154        12860.0
# 5046    1  Апрель     четверг  Мультилифт     Н869МК154         5200.0
# 5049    1  Апрель     четверг    Самосвал     К693СА154          980.0
# 5050    1  Апрель     четверг    Самосвал     К722ВС154         1500.0
# 5051    1  Апрель     четверг    Самосвал     К836ВС154         2220.0
# ...

# %%
bd = bd.drop('perehod_cherez_null', axis=1)

# %%
df.pivot_table(values='size_of_trash', index=['mounth', 'day'], aggfunc='sum')
# Out:
#             size_of_trash
# mounth day
# Август 1          5945.14
#        2          6681.87
#        3          6170.00
#        4          6536.96
#        5          6179.01
# ...                   ...
# Январь 27         5900.83
#        28         5888.60
#        29         5989.61
#        30         5536.06
#        31         5393.41
#
# [365 rows x 1 columns]

# %%
bd[bd['density'] > 140.625]
# Out:
#        day   mounth  day_of_week type_of_car number_of_car  mass_of_trash  \
# 69       2   Январь      суббота    Самосвал     Н200НХ154         2520.0
# 81       2   Январь      суббота    Самосвал     Н587ТТ154         1580.0
# 133      3   Январь  воскресенье    Грузовая     Н419РК154         3300.0
# 185      4   Январь  понедельник    Самосвал     Н200НХ154         4440.0
# 188      4   Январь  понедельник    Грузовая     Н344РТ154         4600.0
# ...    ...      ...          ...         ...           ...            ...
# 21333   31  Декабрь      пятница  Мультилифт     Н416НС154         6800.0
# 21340   31  Декабрь      пятница    Самосвал     Н283УУ154         1860.0
# 21341   31  Декабрь      пятница    Самосвал     Н300УУ154         4960.0
# 21343   31  Декабрь      пятница    Самосвал     Н576ТТ154         1620.0
# 21353   31  Декабрь      пятница    Грузовая     Н515РТ154         2540.0
#
#        size_of_trash     density  tmin  tmax  taverage  perehod_cherez_null
# ...

# %%
bd[bd['mass_of_trash'] > 14420]['type_of_car'].unique()
# Out:
# array(['Задняя', 'Фусо', 'КМУ', 'Самосвал', 'Бункеровоз', 'Мультилифт',
#        'Грузовая'], dtype=object)

# %%
p = np.percentile(bd['density'].dropna(), 75)
p
# Out:
# 178.75

# %%
def null_or_one(x):
    if x['density'] > np.percentile(bd['density'].dropna(), 75):
        return 1
    else:
        return 0
bd['75percentile'] = 0
bd['75percentile'] = bd.apply(lambda x: null_or_one(x), axis=1)
bd
# Out:
#        day   mounth day_of_week type_of_car number_of_car  mass_of_trash  \
# 0        1   Январь     пятница  Бункеровоз     В297КЕ147         4300.0
# 1        1   Январь     пятница  Бункеровоз     К721ВС154         5180.0
# 2        1   Январь     пятница  Бункеровоз     Н726РУ154         5400.0
# 3        1   Январь     пятница  Бункеровоз     Н991НУ154         4960.0
# 4        1   Январь     пятница  Мультилифт     К801ВА154         3220.0
# ...    ...      ...         ...         ...           ...            ...
# 21384   31  Декабрь     пятница      Задняя     Н590ТТ154        23140.0
# 21385   31  Декабрь     пятница      Задняя     Н864ТТ154        10660.0
# 21387   31  Декабрь     пятница      Задняя     Т237ВВ750        15940.0
# 21388   31  Декабрь     пятница      Задняя      Т551РС69        26920.0
# 21389   31  Декабрь     пятница      Задняя      Т799РС69         7300.0
#
#        size_of_trash     density  tmin  tmax  taverage  75percentile
# ...
